# %%
import requests
import pandas as pd
from datetime import datetime

COIN_ID = "bitcoin"
VS_CURRENCY = "usd"
DAYS = "365"

url = f"https://api.coingecko.com/api/v3/coins/{COIN_ID}/market_chart"

params = {
    "vs_currency": VS_CURRENCY,
    "days": DAYS
}

response = requests.get(url, params=params)

data = response.json()

prices = data["prices"]
market_caps = data["market_caps"]
volumes = data["total_volumes"]

rows = []

for i in range(len(prices)):
    rows.append({
        "date": datetime.fromtimestamp(prices[i][0] / 1000),
        "price": prices[i][1],
        "market_cap": market_caps[i][1],
        "volume": volumes[i][1]
    })

df = pd.DataFrame(rows)

df.head()
# Out:
#         date          price    market_cap        volume
# 0 2025-01-22  106182.236820  2.098829e+12  9.534429e+10
# 1 2025-01-23  103673.535095  2.054289e+12  5.503067e+10
# 2 2025-01-24  104067.609912  2.062361e+12  1.024552e+11
# 3 2025-01-25  104835.192536  2.076157e+12  5.141879e+10
# 4 2025-01-26  104796.040777  2.077648e+12  2.274074e+10

# %%
df.to_csv("btc_raw.csv", index=False)
print("Saved!")
# Out:
# Saved!

# %%
from google.colab import drive
drive.mount('/content/drive')
